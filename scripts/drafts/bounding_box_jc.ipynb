# %%
# Mount Drive to Access Data
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!pip install opencv-contrib-python

# %%
import cv2
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define paths
#base_dir = '/content/drive/MyDrive/logo_detection/logo_detection_w281/'
base_dir = '/Users/jetcalz07/Desktop/MIDS/W281_CV/logo_detection_w281/'
image_dir = base_dir + 'data/images/'
os.chdir(base_dir)

# %%
# Load example image
adidas_dir = image_dir + 'adidas/'
adidas_img = cv2.imread(adidas_dir + os.listdir(adidas_dir)[1])
img = cv2.cvtColor(adidas_img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
# Load adidas template
ad_ref_dir = base_dir + 'data/logo_references/adidas/'
ref = cv2.imread(ad_ref_dir + os.listdir(ad_ref_dir)[0])
#adidas_ref_gray = cv2.cvtColor(adidas_ref, cv2.COLOR_RGB2GRAY)
plt.imshow(ref)

# %%
cv2.CascadeClassifier(ad_ref_dir + os.listdir(ad_ref_dir)[0])

# %%
#### Contour Attempt

# Find Canny edges
edged = cv2.Canny(ref, 30, 200)
cv2.waitKey(0)

# Find Contours
cocontours, hierarchy = cv2.findContours(edged, 
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(0)
  
print("Number of Contours found = " + str(len(contours)))
  
# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (0, 255, 0), 3)
  
cv2.imshow('Contours', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# tracker = cv2.legacy.TrackerMOSSE_create()
# bbox = ref #in example, drag on image
# tracker.init(img, ref)
